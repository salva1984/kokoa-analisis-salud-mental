# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ruta = "/content/drive/MyDrive/kokoa-analisis-salud-mental-codespace-refactored-xylophone-g4566pggg7r9hw9jv/data/processed/"

dr1 = pd.read_csv(ruta + "DR1TOT_H_LIMPIO.csv")
duq = pd.read_csv(ruta + "DUQ_H_limpio.csv")
dbq = pd.read_csv(ruta + "DBQ_H_LIMPIO.csv")
bmx = pd.read_csv(ruta + "BMX_H_LIMPIO.csv")

# %%
print(dr1.columns)
# Out:
# Index(['SEQN', 'DRQSDIET', 'DRQSDT1', 'DRQSDT2', 'DRQSDT3', 'DRQSDT4',
#        'DRQSDT5', 'DRQSDT6', 'DRQSDT7', 'DRQSDT8', 'DRQSDT9', 'DRQSDT10',
#        'DRQSDT11', 'DRQSDT12', 'DRQSDT91'],
#       dtype='object')

# %% [markdown]
# #ANÁLISIS DE DR1TOT_H

# %% [markdown]
# Análisis DR1TOT_H – Dieta y recordatorio de 24 horas

# %%
dr1['DRQSDIET'].value_counts(normalize=True) * 100
# Out:
# DRQSDIET
# 2.0    89.473148
# 1.0    10.526852
# Name: proportion, dtype: float64

# %%
dietas = [
'DRQSDT1','DRQSDT2','DRQSDT3','DRQSDT4',
'DRQSDT5','DRQSDT6','DRQSDT7','DRQSDT8',
'DRQSDT9','DRQSDT10','DRQSDT11','DRQSDT12','DRQSDT91'
]

dr1[dietas].sum().sort_values(ascending=False)
# Out:
# DRQSDT91    892983.0
# DRQSDT12    117756.0
# DRQSDT11    107943.0
# DRQSDT10     98130.0
# DRQSDT8      78504.0
# DRQSDT6      58878.0
# DRQSDT4      39252.0
# DRQSDT3      29439.0
# DRQSDT2      19626.0
# DRQSDT1       9813.0
# DRQSDT5          0.0
# DRQSDT9          0.0
# DRQSDT7          0.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

dr1[dietas].sum().sort_values().plot(kind='barh')
plt.title("Tipos de dieta especial más frecuentes")
plt.xlabel("Número de personas")
plt.show()

# %% [markdown]
# #ANÁLISIS DUQ_H

# %% [markdown]
#  Análisis DUQ_H – Consumo de drogas

# %%
sns.countplot(x='DUQ200', data=duq)
plt.title("Uso de marihuana alguna vez")
plt.show()

# %%
plt.hist(duq['DUQ230'], bins=30)
plt.title("Días de consumo de marihuana por mes")
plt.show()

# %%
sns.countplot(x='DUQ240', data=duq)
plt.title("Uso de drogas fuertes")
plt.show()

# %%
sns.countplot(x='DUQ370', data=duq)
plt.title("Uso de drogas inyectadas")
plt.show()

# %% [markdown]
# #ANÁLISIS DBQ_H

# %% [markdown]
#   Análisis DBQ_H – Comportamiento dietético

# %%
sns.countplot(x='DBQ700', data=dbq)
plt.title("Percepción de dieta saludable")
plt.show()

# %%
sns.countplot(x='DBD895', data=dbq)
plt.title("Comidas no preparadas en casa")
plt.show()

# %%
plt.hist(dbq['DBD900'], bins=30)
plt.title("Consumo de comida rápida")
plt.show()

# %%
plt.hist(dbq['DBD905'], bins=30)
plt.title("Comida lista para comer")
plt.show()

# %%
plt.hist(dbq['DBD910'], bins=30)
plt.title("Consumo de comidas congeladas")
plt.show()

# %% [markdown]
# #ANÁLISIS BMX_H

# %% [markdown]
# Análisis BMX_H – Examen corporal

# %%
plt.hist(bmx['BMXBMI'], bins=30)
plt.title("Distribución del IMC")
plt.show()

# %%
plt.hist(bmx['BMXWAIST'], bins=30)
plt.title("Circunferencia de cintura")
plt.show()

# %%
plt.scatter(bmx['BMXBMI'], bmx['BMXWAIST'])
plt.title("Relación IMC vs Cintura")
plt.xlabel("IMC")
plt.ylabel("Cintura")
plt.show()
