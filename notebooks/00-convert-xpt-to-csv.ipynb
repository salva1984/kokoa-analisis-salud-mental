# %%
import pandas as pd

df = pd.read_sas("../data/raw/DPQ_H.xpt", format="xport")

df.to_csv("../data/raw/dpq_h.csv", index=False)

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_sas("../data/raw/DPQ_H.xpt", format="xport")
#       5 df.to_csv("../data/raw/dpq_h.csv", index=False)
#       7 print(df.head())
#
# File /mnt/extssd/Proyectos/data_science/kokoa-analisis-salud-mental/.venv/lib/python3.11/site-packages/pandas/io/sas/sasreader.py:154, in read_sas(filepath_or_buffer, format, index, encoding, chunksize, iterator, compression)
#     151 if format.lower() == "xport":
#     152     from pandas.io.sas.sas_xport import XportReader
# --> 154     reader = XportReader(
#     155         filepath_or_buffer,
#     156         index=index,
#     157         encoding=encoding,
#     158         chunksize=chunksize,
#     159         compression=compression,
#     160     )
#     161 elif format.lower() == "sas7bdat":
# ...
